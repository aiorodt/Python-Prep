# %%
import pandas as pd
import numpy as np

# ==============
# LA TAREA 🎯
# ==============
# Tienes una tabla de ventas de boletos de una aerolínea que parece estar muy sucia.
# Tu tarea es usar las técnicas de la guía para limpiar, preparar y analizar estos datos.
# Resuelve cada problema uno por uno. ¡Mucha suerte!

# =================
# EL DATASET SUCIO
# =================
# No modifiques este código. Úsalo para generar el DataFrame con el que trabajarás.

np.random.seed(42)

datos = {
    'ID_Boleto': [
        'ABC-101', 'DEF-202', 'GHI-303', 'JKL-404', 'ABC-101', 'MNO-505', 'PQR-606', 'STU-707', 'MNO-505', 'VWX-808',
        'YZA-909', 'BCD-110', 'EFG-211', 'HIJ-312', 'KLM-413', 'NOP-514', 'QRS-615', 'TUV-716', 'WXY-817', 'ZAB-918',
        'CDE-119', 'FGH-220', 'IJK-321', 'LMN-422', 'OPQ-523', 'RST-624', 'UVW-725', 'XYZ-826', 'YZA-909', 'ABC-101',
        'BCD-110', 'EFG-211', 'HIJ-312', 'KLM-413', 'NOP-514', 'QRS-615', 'TUV-716', 'WXY-817', 'ZAB-918', 'CDE-119',
        'FGH-220', 'IJK-321', 'LMN-422', 'OPQ-523', 'RST-624', 'UVW-725', 'XYZ-826', 'YZA-909', 'ABC-101', 'BCD-110'
    ],
    'Fecha_Venta': [
        '2024-01-15', '2024-01-15', '2024-01-16', '2024-02-20', np.nan, '2024-03-01', '2024-03-05', '2024-03-10', '2024-03-01', '2024-04-01',
        '2024-04-10', '2024-04-25', '2024-05-01', '2024-05-12', '2024-05-20', '2024-06-05', '2024-06-10', '2024-06-18', '2024-07-01', '2024-07-05',
        '2024-07-10', '2024-07-15', '2024-07-20', '2024-08-01', '2024-08-05', '2024-08-10', '2024-08-15', '2024-08-20', '2024-04-10', '2024-01-15',
        '2024-04-25', '2024-05-01', '2024-05-12', '2024-05-20', '2024-06-05', '2024-06-10', '2024-06-18', '2024-07-01', '2024-07-05', '2024-07-10',
        '2024-07-15', '2024-07-20', '2024-08-01', '2024-08-05', '2024-08-10', '2024-08-15', '2024-08-20', '2024-04-10', np.nan, '2024-04-25'
    ],
    'Origen': [
        'MADRID', 'barcelona ', '  Ciudad de México', 'LIMA', 'MADRID', 'bogota', 'LIMA', 'Buenos Aires', 'bogota', 'Sao Paulo',
        'SANTIAGO', 'Madrid', 'Barcelona', 'CDMX', 'Lima', 'Bogotá', 'Buenos Aires', 'SAO PAULO', 'Santiago', 'Madrid',
        'Barcelona', 'CDMX', 'Lima', 'Bogotá', 'Buenos Aires', 'Sao Paulo', 'Santiago', 'Madrid', 'SANTIAGO', 'MADRID',
        'Madrid', 'Barcelona', 'CDMX', 'Lima', 'Bogotá', 'Buenos Aires', 'SAO PAULO', 'Santiago', 'Madrid', 'Barcelona',
        'CDMX', 'Lima', 'Bogotá', 'Buenos Aires', 'Sao Paulo', 'Santiago', 'Madrid', 'SANTIAGO', 'MADRID', 'Madrid'
    ],
    'Destino': [
        'LIMA', 'MADRID', 'Bogotá', 'sao paulo', 'LIMA', 'MEXICO', 'BOGOTA', 'SANTIAGO', 'MEXICO', 'BUENOS AIRES',
        'BUENOS AIRES', 'LIMA', 'MADRID', 'Bogotá', 'Sao Paulo', 'Mexico', 'Bogotá', 'Santiago', 'Buenos Aires', 'Lima',
        'Madrid', 'Bogota', 'Sao Paulo', 'Mexico', 'Bogota', 'Santiago', 'Buenos Aires', 'Lima', 'BUENOS AIRES', 'LIMA',
        'LIMA', 'MADRID', 'Bogotá', 'Sao Paulo', 'Mexico', 'Bogotá', 'Santiago', 'Buenos Aires', 'Lima', 'Madrid',
        'Bogota', 'Sao Paulo', 'Mexico', 'Bogota', 'Santiago', 'Buenos Aires', 'Lima', 'BUENOS AIRES', 'LIMA', 'LIMA'
    ],
    'Clase': [
        'Economica', 'Premium', 'ECONOMICA', 'Business', 'Economica', 'Business', 'Premium', 'economica', 'Business', 'Premium',
        'ECONOMICA', 'Economica', 'Premium', 'Business', 'Economica', 'Business', 'Premium', 'Economica', 'Premium', 'Economica',
        'Premium', 'Business', 'Economica', 'Business', 'Premium', 'Economica', 'Premium', 'Economica', 'ECONOMICA', 'Economica',
        'Premium', 'Business', 'Economica', 'Business', 'Premium', 'Economica', 'Premium', 'Economica', 'Premium', 'Economica',
        'Premium', 'Business', 'Economica', 'Business', 'Premium', 'Economica', 'Premium', 'Economica', 'ECONOMICA', 'Economica'
    ],
    'Precio_Dolar': [
        250.0, 480.5, 300, '520', 250.0, 500, 450, 270, 500, 480,
        310, 260, 490, 510, 280, 530, 470, 290, 460, 305,
        495, 505, 275, 525, 485, 295, 475, 285, 310, 250.0,
        490, 510, 280, 530, 470, 290, 460, 305, 495, 505,
        275, 525, 485, 295, 475, 285, 99999.0, 310, 'NaN', 260
    ],
    'Pasajero_ID': [
        'A-1234', 'B-5678', 'C-9012', np.nan, 'A-1234', 'D-3456', 'E-7890', 'F-1234', 'D-3456', 'G-5678',
        'H-9012', 'I-3456', 'J-7890', 'K-1234', 'L-5678', 'M-9012', 'N-3456', 'O-7890', 'P-1234', 'Q-5678',
        'R-9012', 'S-3456', 'T-7890', 'U-1234', 'V-5678', 'W-9012', 'X-3456', 'Y-7890', 'H-9012', 'A-1234',
        'I-3456', 'J-7890', 'K-1234', 'L-5678', 'M-9012', 'N-3456', 'O-7890', 'P-1234', 'Q-5678', 'R-9012',
        'S-3456', 'T-7890', 'U-1234', 'V-5678', 'W-9012', 'X-3456', 'Y-7890', 'H-9012', np.nan, 'I-3456'
    ],
    'Metodo_Pago': [
        'Tarjeta', 'Paypal', 'tarjeta', 'Efectivo', 'Tarjeta', 'Paypal', 'Tarjeta', 'Efectivo', 'Paypal', 'Tarjeta',
        'Efectivo', 'tarjeta', 'Paypal', 'Efectivo', 'Tarjeta', 'Paypal', 'Tarjeta', 'Efectivo', 'Tarjeta', 'Paypal',
        'Efectivo', 'Tarjeta', 'Paypal', 'Efectivo', 'Tarjeta', 'Paypal', 'tarjeta', 'Efectivo', 'Efectivo', 'Tarjeta',
        'Tarjeta', 'Paypal', 'Efectivo', 'Tarjeta', 'Paypal', 'Tarjeta', 'Efectivo', 'Tarjeta', 'Paypal', 'Efectivo',
        'Tarjeta', 'Paypal', 'Efectivo', 'Tarjeta', 'Paypal', 'Tarjeta', 'Efectivo', 'Efectivo', 'Efectivo', 'Tarjeta'
    ]
}

df = pd.DataFrame(datos)

# Convertir 'Precio_Dolar' a tipo numérico inicialmente para que los problemas siguientes funcionen.
df['Precio_Dolar'] = pd.to_numeric(df['Precio_Dolar'], errors='coerce')

print("El DataFrame Original:")
print(df)
print("\n" + "="*40 + "\n")

# =================
# LOS PROBLEMAS 🧐
# =================

# Problema 1: Contar los Nulos 🕵️‍♀️
# Objetivo: Encuentra y cuenta la cantidad de valores nulos en cada columna.
# ¿Cuántos valores nulos hay en 'Fecha_Venta' y 'Pasajero_ID'?
# Escribe tu código aquí:


# Problema 2: Eliminar Filas Duplicadas 👯
# Objetivo: Elimina las filas duplicadas basándote en la columna 'ID_Boleto'.
# ¿Cuántas filas te quedan después de este paso?
# Escribe tu código aquí:


# Problema 3: Corregir Nombres de Ciudades 🌍
# Objetivo: Limpia las columnas 'Origen' y 'Destino'.
# 1. Elimina los espacios en blanco al inicio y al final.
# 2. Convierte todo a minúsculas para unificar el formato.
# 3. Corrige el error tipográfico 'CDMX' por 'ciudad de méxico' para unificar con el resto.
# Escribe tu código aquí:


# Problema 4: Unificar Clase 💺
# Objetivo: La columna 'Clase' tiene inconsistencias en la escritura.
# 1. Convierte todos los valores a la misma capitalización (e.g., 'Economica', 'Premium', 'Business').
# 2. Renombra la clase 'Economica' a 'Economy' para usar un estándar internacional.
# Escribe tu código aquí:


# Problema 5: Unificar Método de Pago 💰
# Objetivo: Estandariza los valores de la columna 'Metodo_Pago' a 'Tarjeta', 'Paypal' o 'Efectivo'.
# Tip: Usa el método `.replace()`.
# Escribe tu código aquí:


# Problema 6: Rellenar valores nulos 💉
# Objetivo: Rellena los valores nulos que aún existan en 'Pasajero_ID' y 'Fecha_Venta'.
# 1. Rellena los nulos de 'Pasajero_ID' con el texto 'Desconocido'.
# 2. Rellena los nulos de 'Fecha_Venta' con la fecha más común (la moda).
# Escribe tu código aquí:


# Problema 7: Dividir la Columna 'Pasajero_ID' ✂️
# Objetivo: La columna 'Pasajero_ID' tiene un prefijo de letra y un número.
# 1. Crea una nueva columna llamada 'Tipo_Pasajero' usando el prefijo de letra (A, B, C, etc.).
# 2. Crea otra columna llamada 'Numero_Pasajero' con el valor numérico.
# Escribe tu código aquí:


# Problema 8: Crear Nuevas Columnas a partir de la Fecha 📅
# Objetivo: La columna 'Fecha_Venta' tiene información valiosa.
# 1. Asegúrate de que la columna es de tipo 'datetime'.
# 2. Crea una nueva columna 'Mes_Venta' extrayendo el mes de la fecha.
# 3. Crea otra columna 'Dia_Semana' con el nombre del día de la semana.
# Escribe tu código aquí:


# Problema 9: Manejo de Outliers en 'Precio_Dolar' 💸
# Objetivo: Hay un precio excesivamente alto en la columna 'Precio_Dolar'.
# 1. Identifica el valor atípico (el de 99999.0).
# 2. Reemplaza ese valor con la mediana del resto de los precios de la columna.
# Escribe tu código aquí:


# Problema 10: Filtrado de Datos 🔎
# Objetivo: Después de la limpieza, filtra el DataFrame para mostrar solo los boletos que:
# 1. Se vendieron en 'mayo' o 'junio' (meses).
# 2. Tienen un 'Precio_Dolar' mayor a 400.
# ¿Cuántas filas cumplen con estas condiciones?
# Escribe tu código aquí:


# Problema 11: Inspeccionar la Limpieza ✅
# Objetivo: Usa `df.info()` y `df.describe()` para verificar que todos los tipos de datos sean correctos y que los precios tengan sentido.
# Escribe tu código aquí:


# Problema 12: Resumen Final 📊
# Objetivo: Calcula y muestra el precio promedio de un boleto para cada 'Clase' después de toda la limpieza.
# Tip: Usa `.groupby()`.
# Escribe tu código aquí:
# Out:
# El DataFrame Original:
#    ID_Boleto Fecha_Venta              Origen       Destino      Clase  \
# 0    ABC-101  2024-01-15              MADRID          LIMA  Economica
# 1    DEF-202  2024-01-15          barcelona         MADRID    Premium
# 2    GHI-303  2024-01-16    Ciudad de México        Bogotá  ECONOMICA
# 3    JKL-404  2024-02-20                LIMA     sao paulo   Business
# 4    ABC-101         NaN              MADRID          LIMA  Economica
# 5    MNO-505  2024-03-01              bogota        MEXICO   Business
# 6    PQR-606  2024-03-05                LIMA        BOGOTA    Premium
# 7    STU-707  2024-03-10        Buenos Aires      SANTIAGO  economica
# 8    MNO-505  2024-03-01              bogota        MEXICO   Business
# 9    VWX-808  2024-04-01           Sao Paulo  BUENOS AIRES    Premium
# 10   YZA-909  2024-04-10            SANTIAGO  BUENOS AIRES  ECONOMICA
# 11   BCD-110  2024-04-25              Madrid          LIMA  Economica
# ...

# %%
import pandas as pd
import numpy as np
import io

# =================
# LA TAREA 🎯
# =================
# Tienes una tabla de inventario y ventas de una tienda de licores.
# La tabla está llena de datos inconsistentes y faltantes.
# Tu objetivo es aplicar técnicas de limpieza y preparación de datos
# para dejarla lista para su análisis.

# =========================
# EL DATASET SUCIO ORIGINAL
# =========================
# No modifiques este código. Úsalo para generar el DataFrame con el que trabajarás.

np.random.seed(42)

datos = {
    'ID_Producto': [
        'whisky-101', 'RON-202', 'gin-303', 'Tequila-404', 'whisky-101', 'Vino-505', 'Cerveza-606', 'vino-505',
        'tequila-404', 'Vodka-707', 'WHISKY-101', 'RON-202', 'GIN-303', 'TEQUILA-404', 'VINO-505', 'CERVEZA-606',
        'VODKA-707', 'tequila-404', 'VODKA-707', 'WHISKY-101', 'RON-202', 'GIN-303', 'TEQUILA-404', 'VINO-505',
        'CERVEZA-606', 'VODKA-707', 'whisky-101', 'RON-202', 'GIN-303', 'TEQUILA-404'
    ],
    'Nombre_Producto': [
        'Old Highland', 'Bacardi', 'Tanqueray', 'Don Julio', np.nan, 'Toro', 'Corona', 'Toro',
        'Don Julio', 'Smirnoff', 'Old Highland', 'Bacardi', 'Tanqueray', 'Don Julio', 'Toro', 'Corona',
        'Smirnoff', 'Don Julio', 'Smirnoff', 'Old Highland', 'Bacardi', 'Tanqueray', 'Don Julio', 'Toro',
        'Corona', 'Smirnoff', 'Old Highland', 'Bacardi', np.nan, 'Don Julio'
    ],
    'Categoria': [
        'Whisky', 'Ron', 'Gin', 'Tequila', np.nan, 'Vino', 'Cerveza', 'Vino',
        'Tequila', 'Vodka', 'Whisky', 'Ron', 'Gin', 'Tequila', 'Vino', 'Cerveza',
        'Vodka', 'Tequila', 'Vodka', 'Whisky', 'Ron', 'Gin', 'Tequila', 'Vino',
        'Cerveza', 'Vodka', 'Whisky', 'Ron', 'Gin', 'Tequila'
    ],
    'Cantidad_Stock': [
        150, 200, 180, 250, 150, 300, 400, 300,
        250, 220, 150, 200, np.nan, 250, 300, 400,
        220, 250, 220, 150, 200, 180, 250, 300,
        400, 220, 150, 200, 180, np.nan
    ],
    'Precio_Unitario': [
        '45.50', '30.00', '38.75', '55.00', '45.50', '25.00', '10.00', '25.00',
        '55.00', '42.50', '45.50', '30.00', '38.75', '55.00', '25.00', '10.00',
        '42.50', '55.00', '42.50', '45.50', '30.00', '38.75', '55.00', '25.00',
        '10.00', '42.50', '45.50', '30.00', '38.75', 55.00
    ],
    'Fecha_Recepcion': [
        '2023-11-01', '2023-11-05', '2023-11-10', '2023-11-15', '2023-11-01', '2023-11-20', '2023-11-25', '2023-11-20',
        '2023-11-15', '2023-12-01', '2023-11-01', '2023-11-05', '2023-11-10', '2023-11-15', '2023-11-20', '2023-11-25',
        '2023-12-01', '2023-11-15', '2023-12-01', '2023-11-01', '2023-11-05', '2023-11-10', '2023-11-15', '2023-11-20',
        '2023-11-25', '2023-12-01', '2023-11-01', '2023-11-05', np.nan, '2023-11-15'
    ],
    'Ubicacion': [
        'Estante A', 'Estante B', 'Estante C', 'Estante D', 'Estante A', 'Estante E', 'Estante F', 'Estante E',
        'Estante D', 'Estante G', 'Estante A', 'Estante B', 'Estante C', 'Estante D', 'Estante E', 'Estante F',
        'Estante G', 'Estante D', 'Estante G', 'Estante A', 'Estante B', 'Estante C', 'Estante D', 'Estante E',
        'Estante F', 'Estante G', 'Estante A', 'Estante B', 'Estante C', 'Estante D'
    ],
    'Ventas_Mensuales': [
        50, 65, 40, 80, 50, 75, 120, 75,
        80, 60, 50, 65, 40, 80, 75, 120,
        60, 80, 60, 50, 65, 40, 80, 75,
        120, 60, 50, 65, 40, 80
    ],
    'Proveedor': [
        'Licores S.A.', 'Distribuidora Fina', 'Licores S.A.', 'Bodegas del Sol', 'Licores S.A.', 'Vinos Unidos',
        'Bebidas Globales', 'Vinos Unidos', 'Bodegas del Sol', 'Bebidas Globales', 'Licores S.A.', 'Distribuidora Fina',
        'Licores S.A.', 'Bodegas del Sol', 'Vinos Unidos', 'Bebidas Globales', 'Bebidas Globales', 'Bodegas del Sol',
        'Bebidas Globales', 'Licores S.A.', 'Distribuidora Fina', 'Licores S.A.', 'Bodegas del Sol', 'Vinos Unidos',
        'Bebidas Globales', 'Bebidas Globales', 'Licores S.A.', 'Distribuidora Fina', 'Licores S.A.', 'Bodegas del Sol'
    ]
}

df = pd.DataFrame(datos)

# Convertir 'Precio_Unitario' a tipo numérico inicialmente para que los problemas siguientes funcionen.
df['Precio_Unitario'] = pd.to_numeric(df['Precio_Unitario'], errors='coerce')

print("El DataFrame Original:")
print(df)
print("\n" + "="*40 + "\n")

# =================
# LOS PROBLEMAS 🧐
# =================

# Problema 1: Contar los Nulos 🕵️‍♀️
# Objetivo: Encuentra y cuenta la cantidad de valores nulos en cada columna.
# Escribe tu código aquí:
print("--- Problema 1: Conteo de valores nulos ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")


# Problema 2: Limpiar y Unificar 'ID_Producto' y 'Nombre_Producto' 🧹
# Objetivo: Estandariza estas dos columnas.
# 1. Elimina los duplicados basándote en 'ID_Producto'.
# 2. Convierte 'ID_Producto' y 'Nombre_Producto' a minúsculas.
# Escribe tu código aquí:
print("--- Problema 2: Limpiar y Unificar 'ID_Producto' y 'Nombre_Producto' ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")


# Problema 3: Corregir Nombres en 'Categoria' y 'Proveedor' 🏷️
# Objetivo: Limpia las columnas 'Categoria' y 'Proveedor'.
# 1. Convierte los valores en ambas columnas a un formato estandarizado
#    (e.g., 'Whisky', 'Ron', 'Gin', etc.).
# Escribe tu código aquí:
print("--- Problema 3: Corregir nombres en 'Categoria' y 'Proveedor' ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")


# Problema 4: Rellenar nulos 💉
# Objetivo: Rellena los valores nulos que aún existan.
# 1. En 'Nombre_Producto', rellena los nulos con el valor del mismo 'ID_Producto'.
# 2. En 'Cantidad_Stock', rellena los nulos con 0.
# 3. En 'Categoria', rellena los nulos con 'Desconocida'.
# Escribe tu código aquí:
print("--- Problema 4: Rellenar nulos ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")


# Problema 5: Crear una columna de Ingresos Totales 💲
# Objetivo:
# 1. Asegúrate de que 'Precio_Unitario' y 'Ventas_Mensuales' son de tipo numérico.
# 2. Crea una nueva columna llamada 'Ingresos_Totales' multiplicando
#    'Precio_Unitario' por 'Ventas_Mensuales'.
# Escribe tu código aquí:
print("--- Problema 5: Ingresos Totales ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")


# Problema 6: Análisis de Eficiencia 📈
# Objetivo:
# 1. Crea una nueva columna 'Ratio_Rotacion' que sea el resultado de dividir
#    'Ventas_Mensuales' entre 'Cantidad_Stock'.
# 2. Identifica y muestra los 3 productos con el mayor 'Ratio_Rotacion'.
# Escribe tu código aquí:
print("--- Problema 6: Análisis de Eficiencia (Ratio de Rotación) ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")


# Problema 7: Filtrado de Datos 🔎
# Objetivo: Filtra el DataFrame para mostrar solo los productos que:
# 1. Tienen un 'Precio_Unitario' mayor a 40.
# 2. Pertenecen a la categoría 'Whisky' o 'Tequila'.
# Escribe tu código aquí:
print("--- Problema 7: Filtrado de Datos ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")


# Problema 8: Resumen Final 📊
# Objetivo: Calcula y muestra el 'Ingresos_Totales' promedio por 'Proveedor'.
# Escribe tu código aquí:
print("--- Problema 8: Resumen Final ---")
# Escribe tu código aquí:
print("\n" + "="*40 + "\n")
# Out:
# El DataFrame Original:
#     ID_Producto Nombre_Producto Categoria  Cantidad_Stock  Precio_Unitario  \
# 0    whisky-101    Old Highland    Whisky           150.0            45.50
# 1       RON-202         Bacardi       Ron           200.0            30.00
# 2       gin-303       Tanqueray       Gin           180.0            38.75
# 3   Tequila-404       Don Julio   Tequila           250.0            55.00
# 4    whisky-101             NaN       NaN           150.0            45.50
# 5      Vino-505            Toro      Vino           300.0            25.00
# 6   Cerveza-606          Corona   Cerveza           400.0            10.00
# 7      vino-505            Toro      Vino           300.0            25.00
# 8   tequila-404       Don Julio   Tequila           250.0            55.00
# 9     Vodka-707        Smirnoff     Vodka           220.0            42.50
# 10   WHISKY-101    Old Highland    Whisky           150.0            45.50
# ...
